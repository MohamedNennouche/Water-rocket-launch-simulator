# %%
from waterRocket import WaterRocket
import numpy as np

# %%
myrocket = WaterRocket()

# %%
len(myrocket.air_volume)
# Out:
# 1

# %%
myrocket.air_volume
# Out:
# [0.00135]

# %%
myrocket.calc_air_volume()
# Out:
# [0.00135,
#  0.0013724137931034484,
#  0.0013948275862068968,
#  0.0014172413793103451,
#  0.0014396551724137935,
#  0.0014620689655172419,
#  0.0014844827586206902,
#  0.0015068965517241386,
#  0.001529310344827587,
#  0.0015517241379310353,
#  0.0015741379310344836,
#  0.001596551724137932,
#  0.0016189655172413804,
#  0.0016413793103448287,
#  0.001663793103448277,
#  0.0016862068965517254,
#  0.0017086206896551738,
#  0.0017310344827586221,
#  0.0017534482758620705,
#  0.0017758620689655189,
#  0.0017982758620689672,
#  0.0018206896551724156,
#  0.001843103448275864,
#  0.0018655172413793123,
#  0.0018879310344827606,
#  0.001910344827586209,
#  0.0019327586206896574,
#  0.0019551724137931055,
#  0.0019775862068965536,
#  0.002,
#  0.002,
#  0.0026670244263508514,
#  0.0033340488527017027,
#  0.004001073279052554,
#  0.0046680977054034045,
#  0.005335122131754255,
#  0.006002146558105106,
#  0.006669170984455957,
#  0.007336195410806808,
#  0.00800321983715766,
# ...

# %%
len(myrocket.air_volume)
# Out:
# 599

# %%
myrocket.calc_all_caracteristics()
# Out:
# ([0.00135,
#   0.0013724137931034484,
#   0.0013948275862068968,
#   0.0014172413793103451,
#   0.0014396551724137935,
#   0.0014620689655172419,
#   0.0014844827586206902,
#   0.0015068965517241386,
#   0.001529310344827587,
#   0.0015517241379310353,
#   0.0015741379310344836,
#   0.001596551724137932,
#   0.0016189655172413804,
#   0.0016413793103448287,
#   0.001663793103448277,
#   0.0016862068965517254,
#   0.0017086206896551738,
#   0.0017310344827586221,
#   0.0017534482758620705,
#   0.0017758620689655189,
#   0.0017982758620689672,
#   0.0018206896551724156,
#   0.001843103448275864,
#   0.0018655172413793123,
#   0.0018879310344827606,
#   0.001910344827586209,
#   0.0019327586206896574,
#   0.0019551724137931055,
#   0.0019775862068965536,
#   0.002,
#   0.002,
#   0.0026670244263508514,
#   0.0033340488527017027,
#   0.004001073279052554,
#   0.0046680977054034045,
#   0.005335122131754255,
#   0.006002146558105106,
#   0.006669170984455957,
#   0.007336195410806808,
# ...

# %%
len(myrocket.air_volume),len(myrocket.air_pressure),len(myrocket.ejection_velocity),len(myrocket.time),len(myrocket.dust),len(myrocket.rocket_mass),len(myrocket.rampe_tilt),len(myrocket.v_rocket),len(myrocket.air_resistance),len(myrocket.x),len(myrocket.y),len(myrocket.acceleration_y)
# Out:
# (599, 599, 599, 599, 599, 599, 599, 599, 599, 599, 599, 599)

# %%
import pandas as pd

# %%
mydata = myrocket.create_df()

# %%
len(myrocket.air_volume),len(myrocket.air_pressure),len(myrocket.ejection_velocity),len(myrocket.time),len(myrocket.dust),len(myrocket.rocket_mass),len(myrocket.rampe_tilt),len(myrocket.v_rocket),len(myrocket.air_resistance),len(myrocket.x),len(myrocket.y),len(myrocket.acceleration_y)
# Out:
# (599, 599, 599, 599, 599, 599, 599, 599, 599, 599, 599, 599)

# %%
mydata
# Out:
#      Air volume    Air pressure       Time  Ejection velocity        Dust  \
# 0      0.001350  1000000.000000   0.000000          44.768489  127.247809
# 1      0.001372   982013.536432   0.007902          44.364049  124.959071
# 2      0.001395   964605.129790   0.015870          43.969064  122.743889
# 3      0.001417   947747.354015   0.023901          43.583161  120.598774
# 4      0.001440   931414.491018   0.031997          43.205987  118.520453
# ..          ...             ...        ...                ...         ...
# 335    0.000000        0.000000  15.320883           0.000000    0.000000
# 336    0.000000        0.000000  15.370883           0.000000    0.000000
# 337    0.000000        0.000000  15.420883           0.000000    0.000000
# 338    0.000000        0.000000  15.470883           0.000000    0.000000
# 339    0.000000        0.000000  15.520883           0.000000    0.000000
#
#      Rocket mass       Tilt  Rocket velocity  Air resistance          x  \
# ...

# %%
myrocket.createPDF()
